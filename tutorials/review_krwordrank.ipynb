# %%
import glob
import json
import sys

sys.path.append('/Users/hyunjoongkim/git/soy/')

import soy
from soy.nlp.extractors import KR_WordRank

# %%
def get_texts_scores(fname):
    with open(fname, encoding='utf-8') as f:
        docs = [doc.lower().replace('\n','').split('\t') for doc in f]
        docs = [doc for doc in docs if len(doc) == 2]
        
        if not docs:
            return [], []
        
        texts, scores = zip(*docs)
        return list(texts), list(scores)

# La La Land
fname = '134963_norm.txt'
texts, scores = get_texts_scores(fname)

# %%
texts[:5]
# Out:
# ['시사회에서 보고왔습니다동화와 재즈뮤지컬의 만남 지루하지않고 재밌습니다',
#  '사랑과 꿈 그 흐름의 아름다움을 음악과 영상으로 최대한 담아놓았다 배우들 연기는 두말할것없고',
#  '지금껏 영화 평가 해본 적이 없는데 진짜 최고네요 색감 스토리 음악 연기 모두ㅜㅜ최고입니다',
#  '방금 시사회 보고 왔어요 배우들 매력이 눈을 뗄 수가 없게 만드네요 한편의 그림 같은 장면들도 많고 음악과 춤이 눈과 귀를 사로 잡았어요 한번 더 보고 싶네요',
#  '초반부터 끝까지 재미있게 잘보다가 결말에서 고국마 왕창먹음 힐링 받는 느낌들다가 막판에 기분 잡쳤습니다 마치 감독이 하고싶은 말은 너희들이 원하는 결말은 이거지 하지만 현실은 이거다 라고 말하고 싶었나보군요']

# %%
kr_wordrank = KR_WordRank()
keywords, rank, graph = kr_wordrank.extract(texts, max_iter=20)

len(keywords), len(rank), len(graph)
# Out:
# scan vocabs ...
# num vocabs = 15097
# done
# (2615, 15092, 15092)

# %%
kr_wordrank.vocabulary[('star', 'L')], rank[1449]
# Out:
# (1449, 1.9323876901223311)

# %%
kr_wordrank.vocabulary[('city', 'L')], rank[1911]
# Out:
# (1911, 1.8655723314245778)

# %%
kr_wordrank.vocabulary[('꿈', 'L')], rank[44]
# Out:
# (44, 26.439955069302826)

# %%
for word, r in sorted(keywords.items(), key=lambda x:x[1], reverse=True)[:200]:
    print('%8s:\t%.4f' % (word, r))
# Out:
#       영화:	229.7378
#      관람객:	112.4468
#       너무:	78.4532
#       음악:	37.6427
#       정말:	37.2659
#      마지막:	34.9867
#       최고:	22.4419
#       사랑:	21.1400
#      뮤지컬:	20.7444
#       꿈을:	19.5305
#      여운이:	19.4087
#       보고:	19.4067
#       아름:	18.6714
#       진짜:	18.5632
#       영상:	18.1253
#       좋았:	17.8600
#       노래:	16.9039
#      스토리:	16.2635
#       좋은:	15.4776
#       그냥:	15.2143
#       현실:	15.0809
#       생각:	14.6266
#       인생:	14.2734
#       좋고:	14.0073
#       지루:	13.8718
#       다시:	13.7833
#       감동:	13.4835
#       느낌:	12.3092
#       ㅠㅠ:	12.1389
#       좋아:	11.9576
#       보는:	11.9049
#       계속:	11.5080
#       조금:	11.4964
#       연기:	11.4854
#       많이:	11.0434
#      그리고:	11.0174
#       장면:	11.0161
#       있는:	10.7788
#       하는:	10.5779
#       결말:	10.5155
#       재미:	10.2628
#       남는:	10.0160
#       사람:	9.8294
#       재밌:	9.8229
#       처음:	9.5491
#       모두:	9.4354
#      봤는데:	9.2879
#      하지만:	8.9908
#      라이언:	8.7248
#      눈물이:	8.7097
#       내내:	8.7016
#       연출:	8.5823
#       모든:	8.5404
#       이런:	8.4710
#       재즈:	8.2799
#       같은:	8.1783
#       of:	8.0640
#       별로:	8.0456
#       대한:	7.8494
#       기대:	7.7770
#       ㅎㅎ:	7.5165
#       엔딩:	7.4030
#       배우:	7.3445
#       내가:	7.2183
#      이렇게:	7.1163
#       평점:	7.1140
#       올해:	7.1008
#      이야기:	7.0935
#       꿈과:	6.9037
#       추천:	6.7018
#       그런:	6.6355
#       함께:	6.6094
#      중간에:	6.4384
#       보면:	6.3980
#       슬픈:	6.3753
#       감독:	6.3688
#       없는:	6.3447
#       가슴:	6.3315
#      봤어요:	6.3151
#       엠마:	6.2990
#       아니:	6.2114
#       가장:	6.2003
#       한번:	6.1651
#       마음:	6.1261
#       특히:	6.1006
#       하나:	6.0712
#       내용:	6.0693
#       10:	6.0687
#       라라:	5.9224
#       서로:	5.8310
#       같다:	5.8271
#      ost:	5.7374
#       않은:	5.6906
#       행복:	5.6603
#       좋다:	5.6004
#       남자:	5.5859
#       위한:	5.5596
#       없다:	5.4074
#       귀가:	5.3846
#      피아노:	5.2916
#       멋진:	5.2559
#       색감:	5.2493
#       약간:	5.2428
#       기분:	5.2004
#       있다:	5.1789
#       완벽:	5.1371
#      끝까지:	5.1347
#      그래도:	5.1080
#       강추:	4.9447
#       않는:	4.9104
#       우리:	4.8534
#       아닌:	4.8439
#      고슬링:	4.8383
#       감정:	4.8232
#       많은:	4.8166
#       눈빛:	4.6842
#       하고:	4.6756
#       시간:	4.6514
#       아주:	4.5940
#       두번:	4.5792
#       나는:	4.5625
#      같아요:	4.5277
#       다른:	4.4985
#       있었:	4.4720
#      보세요:	4.4246
#      아직도:	4.4173
#       보기:	4.3809
#       뭔가:	4.2822
#       싶은:	4.2220
#      주인공:	4.2187
#       말이:	4.1795
#       여자:	4.1773
#       슬프:	4.1670
#       환상:	4.0856
#       않고:	4.0606
#       ㅋㅋ:	3.9995
#      로맨스:	3.9927
#       모르:	3.9808
#       살짝:	3.9719
#       대해:	3.9698
#       황홀:	3.9568
#       봤다:	3.9477
#      끝나고:	3.9419
#       지금:	3.9319
#       ㅜㅜ:	3.9145
#       위해:	3.8887
#       보러:	3.8879
#      그렇게:	3.8841
#       같이:	3.8480
#       주는:	3.8100
#       결국:	3.7359
#       위플:	3.7290
#       근데:	3.6977
#       이루:	3.6885
#       저는:	3.6644
#       여주:	3.6543
#       동화:	3.6414
#      예쁘고:	3.6236
#       작품:	3.6072
#      꿈꾸는:	3.5883
#       싶다:	3.5495
#       혼자:	3.5351
#      즐거운:	3.5325
#       나도:	3.5047
#       되는:	3.4646
#       것이:	3.4359
#       역시:	3.4359
#      솔직히:	3.4307
#      기억에:	3.4284
#       꿈이:	3.4145
#       몰입:	3.3854
#       아쉬:	3.3800
#       꿈에:	3.3407
#      만드는:	3.2722
#       배경:	3.2646
#       완전:	3.2091
#      보다가:	3.1920
#       열정:	3.1899
#       부분:	3.1896
#       공감:	3.1408
#      좋네요:	3.0892
#       매력:	3.0494
#      봤네요:	3.0396
#       봐서:	2.9916
#       엄청:	2.9707
#       이해:	2.9688
#       봐야:	2.9499
#       예술:	2.9488
#      갈수록:	2.9068
#       봐도:	2.9056
#       뻔한:	2.8981
#       이상:	2.8952
#       매우:	2.8916
#       개인:	2.8571
#       만든:	2.8458
#       꿈은:	2.8415
#      남네요:	2.8119
#       것을:	2.7935
#       나의:	2.7912
#       예쁜:	2.7842

# %%
# remove subtokens

subtokens = set()
keywords_ = {}

for word, r in sorted(keywords.items(), key=lambda x:x[1], reverse=True):
    subs = {word[:e] for e in range(2, len(word)+1)}
    
    is_subtoken = False
    for sub in subs:
        if sub in subtokens:
            is_subtoken = True
            break
    
    if not is_subtoken:
        keywords_[word] = r
        subtokens.update(subs)

len(keywords), len(keywords_)
# Out:
# (3109, 2609)

# %%
for word, r in sorted(keywords.items(), key=lambda x:x[1], reverse=True)[:200]:
    print('%8s:\t%.4f' % (word, r))
# Out:
#       영화:	1.2473
#      관람객:	0.6936
#       너무:	0.5613
#       정말:	0.2651
#      마지막:	0.2387
#       음악:	0.2181
#      최고의:	0.1401
#       보고:	0.1387
#      뮤지컬:	0.1379
#      여운이:	0.1342
#       진짜:	0.1340
#       꿈을:	0.1340
#       사랑:	0.1221
#       아름:	0.1182
#       좋았:	0.1180
#       좋은:	0.1126
#       영상:	0.1054
#       노래:	0.1010
#       그냥:	0.0985
#      스토리:	0.0974
#       생각:	0.0933
#       현실:	0.0925
#       다시:	0.0925
#       인생:	0.0916
#       좋고:	0.0877
#       지루:	0.0866
#       보는:	0.0840
#       계속:	0.0800
#       좋아:	0.0784
#       많이:	0.0774
#       있는:	0.0768
#       조금:	0.0762
#       감동:	0.0762
#      그리고:	0.0760
#       장면:	0.0739
#       남는:	0.0737
#       하는:	0.0724
#       모두:	0.0695
#       재미:	0.0650
#       연기:	0.0648
#       재밌:	0.0645
#       사람:	0.0634
#       결말:	0.0628
#       느낌:	0.0626
#       ㅠㅠ:	0.0621
#      눈물이:	0.0613
#       처음:	0.0607
#       내내:	0.0605
#      봤는데:	0.0593
#       이런:	0.0590
#       같은:	0.0589
#       모든:	0.0588
#      라이언:	0.0578
#       of:	0.0576
#       대한:	0.0557
#      하지만:	0.0554
#       올해:	0.0525
#       재즈:	0.0512
#      이렇게:	0.0503
#       꿈과:	0.0495
#       연출:	0.0487
#       기대:	0.0486
#       별로:	0.0485
#       없는:	0.0474
#       내가:	0.0470
#       평점:	0.0462
#      중간에:	0.0453
#       그런:	0.0451
#       함께:	0.0449
#       엔딩:	0.0447
#       배우:	0.0442
#       보면:	0.0435
#       슬픈:	0.0433
#       가장:	0.0430
#       가슴:	0.0424
#      이야기:	0.0410
#       특히:	0.0408
#       한번:	0.0407
#       위한:	0.0402
#       ㅎㅎ:	0.0401
#       마음:	0.0399
#       ..:	0.0398
#       아니:	0.0395
#       하나:	0.0395
#       엠마:	0.0394
#       멋진:	0.0387
#       않은:	0.0383
#       귀가:	0.0381
#       감독:	0.0380
#       서로:	0.0377
#       내용:	0.0374
#       라라:	0.0371
#       행복:	0.0364
#       10:	0.0361
#       약간:	0.0357
#      끝까지:	0.0356
#      피아노:	0.0350
#       남자:	0.0345
#       싶은:	0.0336
#       않는:	0.0335
#       나는:	0.0331
#       기분:	0.0330
#       많은:	0.0328
#       추천:	0.0327
#       아주:	0.0324
#      그래도:	0.0321
#       감정:	0.0310
#       뭔가:	0.0309
#       보기:	0.0309
#       다른:	0.0306
#       완벽:	0.0306
#       말이:	0.0304
#       하고:	0.0302
#       시간:	0.0301
#       아닌:	0.0301
#      아직도:	0.0300
#      고슬링:	0.0298
#       색감:	0.0296
#       있었:	0.0295
#       우리:	0.0294
#       같다:	0.0291
#       눈빛:	0.0288
#      끝나고:	0.0286
#       두번:	0.0283
#      봤어요:	0.0281
#       주는:	0.0275
#       살짝:	0.0274
#      주인공:	0.0273
#      즐거운:	0.0272
#       대해:	0.0268
#       같이:	0.0267
#       좋다:	0.0266
#       있다:	0.0264
#       황홀:	0.0262
#       슬프:	0.0261
#       지금:	0.0260
#       위해:	0.0260
#       여자:	0.0258
#       보러:	0.0258
#      그렇게:	0.0258
#      꿈꾸는:	0.0256
#       환상:	0.0255
#       없다:	0.0251
#       모르:	0.0248
#      솔직히:	0.0248
#       결국:	0.0248
#       되는:	0.0244
#       않고:	0.0243
#      기억에:	0.0242
#       혼자:	0.0239
#      예쁘고:	0.0238
#       것이:	0.0237
#       근데:	0.0237
#       여주:	0.0233
#       나도:	0.0233
#      만드는:	0.0232
#       이루:	0.0231
#       꿈이:	0.0231
#      보다가:	0.0229
#      보세요:	0.0228
#       ㅋㅋ:	0.0228
#      ost:	0.0226
#       역시:	0.0226
#      로맨스:	0.0225
#       저는:	0.0223
#       완전:	0.0223
#       나의:	0.0219
#       꿈에:	0.0219
#       동화:	0.0219
#       ㅜㅜ:	0.0217
#       아쉬:	0.0213
#       봐서:	0.0209
#       위플:	0.0209
#       봐도:	0.0209
#       부분:	0.0209
#       매우:	0.0206
#       만든:	0.0206
#       to:	0.0205
#       몰입:	0.0204
#       엄청:	0.0203
#       뻔한:	0.0202
#      같아요:	0.0201
#       예쁜:	0.0200
#       작품:	0.0199
#       이건:	0.0197
#      갈수록:	0.0197
#       :):	0.0197
#       꿈은:	0.0194
#       강추:	0.0191
#       제일:	0.0190
#       열정:	0.0189
#       배경:	0.0188
#       봐야:	0.0186
#       없었:	0.0186
#       만들:	0.0186
#       공감:	0.0186
#      봤습니:	0.0185
#       이해:	0.0184
#       나오:	0.0183
#       있어:	0.0182

# %%
from collections import defaultdict


class KR_WordRank:
    
    def __init__(self, min_count=5, max_length=10, sum_weight=100):
        self.min_count = min_count
        self.max_length = max_length
        self.sum_weight = sum_weight
        self.vocabulary = {}
        self.index2vocab = []

    def scan_vocabs(self, docs, verbose=True):
        self.vocabulary = {}
        if verbose:
            print('scan vocabs ... ')
        
        counter = {}        
        for doc in docs:
            
            for token in doc.split():
                len_token = len(token)
                counter[(token, 'L')] = counter.get((token, 'L'), 0) + 1
                
                for e in range(1, min(len(token), self.max_length)):
                    if (len_token - e) > self.max_length:
                        continue
                        
                    l_sub = (token[:e], 'L')
                    r_sub = (token[e:], 'R')
                    counter[l_sub] = counter.get(l_sub, 0) + 1
                    counter[r_sub] = counter.get(r_sub, 0) + 1
        
        counter = {token:freq for token, freq in counter.items() if freq >= self.min_count}
        for token, _ in sorted(counter.items(), key=lambda x:x[1], reverse=True):
            self.vocabulary[token] = len(self.vocabulary)
            
        self._build_index2vocab()
        
        if verbose:
            print('num vocabs = %d' % len(counter))        
        return counter
    
    def _build_index2vocab(self):
        self.index2vocab = [vocab for vocab, index in sorted(self.vocabulary.items(), key=lambda x:x[1])]
    
    def extract(self, docs, beta=0.85, max_iter=10, verbose=True, vocabulary={}, bias={}, rset={}):
        rank, graph = self.train(docs, beta, max_iter, verbose, vocabulary, bias)
        
        lset = {self.int2token(idx)[0]:r for idx, r in rank.items() if self.int2token(idx)[1] == 'L'}
        if not rset:
            rset = {self.int2token(idx)[0]:r for idx, r in rank.items() if self.int2token(idx)[1] == 'R'}
        
        keywords = self._select_keywords(lset, rset)
        keywords = self._filter_compounds(keywords)
        
        return keywords, rank, graph
        
    def _select_keywords(self, lset, rset):
        keywords = {}
        for word, r in sorted(lset.items(), key=lambda x:x[1], reverse=True):
            len_word = len(word)
            if len_word == 1:
                continue

            is_compound = False
            for e in range(2, len_word):
                if (word[:e] in keywords) and (word[:e] in rset):
                    is_compound = True
                    break

            if not is_compound:
                keywords[word] = r

        return keywords
    
    def _filter_compounds(self, keywords):
        keywords_= {}
        for word, r in sorted(keywords.items(), key=lambda x:x[1], reverse=True):
            len_word = len(word)

            if len_word <= 2:
                keywords_[word] = r
                continue

            if len_word == 3:
                if word[:2] in keywords_:
                    continue

            is_compound = False
            for e in range(2, len_word - 1):
                if (word[:e] in keywords) and (word[:e] in keywords):
                    is_compound = True
                    break

            if not is_compound:
                keywords_[word] = r
        
        return keywords_
    
    def train(self, docs, beta=0.85, max_iter=10, verbose=True, vocabulary={}, bias={}):
        if (not vocabulary) and (not self.vocabulary):
            self.scan_vocabs(docs, verbose)
        elif (not vocabulary):
            self.vocabulary = vocabulary
            self._build_index2vocab()
        
        graph = self._construct_word_graph(docs)       
        
        dw = self.sum_weight / len(self.vocabulary)
        rank = {node:dw for node in graph.keys()}
        
        for num_iter in range(1, max_iter + 1):
            rank = self._update(rank, graph, bias, dw, beta)
            sys.stdout.write('\riter = %d' % num_iter)
        print('\rdone')
        
        return rank, graph
            
    def token2int(self, token):
        return self.vocabulary.get(token, -1)

    def int2token(self, index):
        return self.index2vocab[index] if (0 <= index < len(self.index2vocab)) else None
    
    def _construct_word_graph(self, docs):
        def normalize(graph):
            # TODO: check normalize는 inbound 기준인가? outbound 기준인가? 
            # input은 from_to graph인데, output은 to_from graph로 가야 inbound로 쓸 수 있음
            graph_ = defaultdict(lambda: defaultdict(lambda: 0))
            for from_, to_dict in graph.items():
                sum_ = sum(to_dict.values())
                for to_, w in to_dict.items():
                    graph_[to_][from_] = w / sum_
            return graph_
        
        graph = defaultdict(lambda: defaultdict(lambda: 0))        
        for doc in docs:

            tokens = doc.split()

            if not tokens:
                continue

            links = []
            for token in tokens:
                links += self._intra_link(token)

            if len(tokens) > 1:
                tokens = [tokens[-1]] + tokens + [tokens[0]]
                links += self._inter_link(tokens)

            links = self._check_token(links)
            if not links:
                continue
            
            links = self._encode_token(links)
            for l_node, r_node in links:
                graph[l_node][r_node] += 1
                graph[r_node][l_node] += 1
            
        graph = normalize(graph)        
        return graph
    
    def _intra_link(self, token):
        links = []
        len_token = len(token)
        for e in range(1, min(len_token, 10)):
            if (len_token - e) > self.max_length:
                continue
            links.append( ((token[:e], 'L'), (token[e:], 'R')) )            
        return links
    
    def _inter_link(self, tokens):
        def rsub_to_token(t_left, t_curr):
            return [((t_left[-b:], 'R'), (t_curr, 'L')) for b in range(1, min(10, len(t_left)))]
        def token_to_lsub(t_curr, t_rigt):
            return [((t_curr, 'L'), (t_rigt[:e], 'L')) for e in range(1, min(10, len(t_rigt)))]

        links = []
        for i in range(1, len(tokens)-1):
            links += rsub_to_token(tokens[i-1], tokens[i])
            links += token_to_lsub(tokens[i], tokens[i+1])
        return links
    
    def _check_token(self, token_list):
        return [(token[0], token[1]) for token in token_list if (token[0] in self.vocabulary and token[1] in self.vocabulary)]
    
    def _encode_token(self, token_list):
        return [(self.vocabulary[token[0]],self.vocabulary[token[1]]) for token in token_list]
    
    def _update(self, rank, graph, bias, dw, beta):
        rank_new = {}
        for to_node, from_dict in graph.items():
            rank_new[to_node] = sum([w * rank[from_node] for from_node, w in from_dict.items()])
            rank_new[to_node] = beta * rank_new[to_node] + (1 - beta) * bias.get(to_node, dw)
        return rank_new

# %%
kr_wordrank = KR_WordRank()
keywords, rank, graph = kr_wordrank.extract(texts, max_iter=50)
# Out:
# scan vocabs ...
# num vocabs = 15990
# done

# %%
len(keywords), len(rank), len(graph)
# Out:
# (3108, 15982, 15982)

# %%
lset = {kr_wordrank.int2token(idx)[0]:r for idx, r in rank.items() if kr_wordrank.int2token(idx)[1] == 'L'}
rset = {kr_wordrank.int2token(idx)[0]:r for idx, r in rank.items() if kr_wordrank.int2token(idx)[1] == 'R'}

# %%
keywords = {}
for word, r in sorted(lset.items(), key=lambda x:x[1], reverse=True):
    len_word = len(word)
    if len_word == 1:
        continue
    
    is_lr = False
    for e in range(2, len_word):
        if (word[:e] in keywords) and (word[:e] in rset):
            is_lr = True
            break
    
    if not is_lr:
        keywords[word] = r

# %%
keywords_= {}
for word, r in sorted(keywords.items(), key=lambda x:x[1], reverse=True):
    len_word = len(word)
    
    if len_word <= 2:
        keywords_[word] = r
        continue
    
    if len_word == 3:
        if word[:2] in keywords_:
            continue
    
    is_compound = False
    for e in range(2, len_word - 1):
        if (word[:e] in keywords) and (word[:e] in keywords):
            is_compound = True
            break
    
    if not is_compound:
        keywords_[word] = r

# %%
len(keywords), '-->', len(keywords_)
# Out:
# (6632, '-->', 3108)

# %%
for word in ['위플', '위플래', '위플래시', '위플래쉬', '래시', '래쉬']:
    print(word, keywords.get(word, 0))
# Out:
# 위플 0.020931881524936084
# 위플래 0.01843499086103446
# 위플래시 0.009659070791532843
# 위플래쉬 0.016442855294109597
# 래시 0
# 래쉬 0

# %%
'위플래' in keywords, '위플래시' in keywords, '위플래쉬' in keywords
# Out:
# (True, True, True)

# %%
for word, r in sorted(keywords_.items(), key=lambda x:x[1], reverse=True)[:50]:
    print('%15s:\t%.4f' % (word, r))
# Out:
#              영화:	1.2473
#             관람객:	0.6936
#              관람:	0.6360
#              너무:	0.5613
#              정말:	0.2651
#             마지막:	0.2387
#              음악:	0.2181
#             최고의:	0.1401
#              보고:	0.1387
#             뮤지컬:	0.1379
#             여운이:	0.1342
#              진짜:	0.1340
#              꿈을:	0.1340
#              최고:	0.1273
#              사랑:	0.1221
#              아름:	0.1182
#              좋았:	0.1180
#              좋은:	0.1126
#              영상:	0.1054
#              노래:	0.1010
#              그냥:	0.0985
#             스토리:	0.0974
#              마지:	0.0953
#              생각:	0.0933
#              현실:	0.0925
#              다시:	0.0925
#              인생:	0.0916
#              좋고:	0.0877
#              지루:	0.0866
#              여운:	0.0847
#              보는:	0.0840
#              계속:	0.0800
#              뮤지:	0.0794
#              좋아:	0.0784
#              많이:	0.0774
#              있는:	0.0768
#              조금:	0.0762
#              감동:	0.0762
#             그리고:	0.0760
#              스토:	0.0739
#              장면:	0.0739
#              남는:	0.0737
#              하는:	0.0724
#              모두:	0.0695
#              재미:	0.0650
#              연기:	0.0648
#              재밌:	0.0645
#              사람:	0.0634
#              결말:	0.0628
#              느낌:	0.0626

# %%
for word, r in sorted(keywords.items(), key=lambda x:x[1], reverse=True)[:500]:
    print('%15s:\t%.4f' % (word, r))
# Out:
#              영화:	1.2473
#             관람객:	0.6936
#              관람:	0.6360
#              너무:	0.5613
#              정말:	0.2651
#             마지막:	0.2387
#              음악:	0.2181
#            아름다운:	0.1476
#             최고의:	0.1401
#              보고:	0.1387
#             뮤지컬:	0.1379
#             여운이:	0.1342
#              진짜:	0.1340
#              꿈을:	0.1340
#              최고:	0.1273
#              사랑:	0.1221
#              아름:	0.1182
#              좋았:	0.1180
#              좋은:	0.1126
#              영상:	0.1054
#              노래:	0.1010
#              그냥:	0.0985
#             스토리:	0.0974
#              마지:	0.0953
#              생각:	0.0933
#              현실:	0.0925
#              다시:	0.0925
#              인생:	0.0916
#              좋고:	0.0877
#              지루:	0.0866
#              여운:	0.0847
#              보는:	0.0840
#             아름다:	0.0819
#           관람객너무:	0.0815
#              계속:	0.0800
#              뮤지:	0.0794
#              좋아:	0.0784
#              많이:	0.0774
#              있는:	0.0768
#              조금:	0.0762
#              감동:	0.0762
#             그리고:	0.0760
#              스토:	0.0739
#              장면:	0.0739
#              남는:	0.0737
#              하는:	0.0724
#              모두:	0.0695
#              재미:	0.0650
#              연기:	0.0648
#              재밌:	0.0645
#              사람:	0.0634
#              결말:	0.0628
#              느낌:	0.0626
#              ㅠㅠ:	0.0621
#             눈물이:	0.0613
#              처음:	0.0607
#              내내:	0.0605
#             봤는데:	0.0593
#              이런:	0.0590
#              같은:	0.0589
#              모든:	0.0588
#             라이언:	0.0578
#              of:	0.0576
#            라라랜드:	0.0562
#            아름답고:	0.0561
#              대한:	0.0557
#             하지만:	0.0554
#            좋았어요:	0.0534
#           관람객정말:	0.0531
#              올해:	0.0525
#              재즈:	0.0512
#             이렇게:	0.0503
#              꿈과:	0.0495
#              연출:	0.0487
#              기대:	0.0486
#              별로:	0.0485
#              눈물:	0.0475
#              없는:	0.0474
#              내가:	0.0470
#              평점:	0.0462
#             중간에:	0.0453
#              그런:	0.0451
#              함께:	0.0449
#              엔딩:	0.0447
#              배우:	0.0442
#              보면:	0.0435
#              슬픈:	0.0433
#              가장:	0.0430
#              가슴:	0.0424
#             아름답:	0.0421
#             좋았다:	0.0417
#             이야기:	0.0410
#              특히:	0.0408
#              한번:	0.0407
#             재밌게:	0.0406
#              위한:	0.0402
#              ㅎㅎ:	0.0401
#           관람객음악:	0.0400
#              마음:	0.0399
#              ..:	0.0398
#              그리:	0.0396
#              아니:	0.0395
#              하나:	0.0395
#          관람객마지막:	0.0395
#              엠마:	0.0394
#           좋았습니다:	0.0391
#            관람객영:	0.0387
#              멋진:	0.0387
#           개인적으로:	0.0383
#              않은:	0.0383
#              귀가:	0.0381
#              감독:	0.0380
#              서로:	0.0377
#              내용:	0.0374
#              라라:	0.0371
#              행복:	0.0364
#              10:	0.0361
#              약간:	0.0357
#             끝까지:	0.0356
#             라라랜:	0.0353
#            관람객재:	0.0352
#             피아노:	0.0350
#              남자:	0.0345
#            관람객음:	0.0337
#              싶은:	0.0336
#              않는:	0.0335
#              나는:	0.0331
#              기분:	0.0330
#              많은:	0.0328
#              추천:	0.0327
#              아주:	0.0324
#           관람객영화:	0.0324
#             그래도:	0.0321
#            오랜만에:	0.0315
#            봤습니다:	0.0314
#              중간:	0.0311
#              감정:	0.0310
#              뭔가:	0.0309
#              보기:	0.0309
#             좋았어:	0.0307
#              다른:	0.0306
#              완벽:	0.0306
#              말이:	0.0304
#              하고:	0.0302
#              시간:	0.0301
#              아닌:	0.0301
#             아직도:	0.0300
#             고슬링:	0.0298
#              색감:	0.0296
#              있었:	0.0295
#              우리:	0.0294
#              같다:	0.0291
#         관람객아름다운:	0.0289
#              눈빛:	0.0288
#             끝나고:	0.0286
#          관람객뮤지컬:	0.0286
#              두번:	0.0283
#             봤어요:	0.0281
#              라이:	0.0280
#              이야:	0.0279
#              주는:	0.0275
#              살짝:	0.0274
#              하지:	0.0274
#             주인공:	0.0273
#             즐거운:	0.0272
#              대해:	0.0268
#              같이:	0.0267
#              좋다:	0.0266
#              있다:	0.0264
#              봤는:	0.0263
#              황홀:	0.0262
#              슬프:	0.0261
#              지금:	0.0260
#              위해:	0.0260
#              여자:	0.0258
#              보러:	0.0258
#             그렇게:	0.0258
#             꿈꾸는:	0.0256
#              환상:	0.0255
#             좋았고:	0.0254
#             슬프고:	0.0253
#            관람객너:	0.0251
#              없다:	0.0251
#            관람객아:	0.0249
#              모르:	0.0248
#             솔직히:	0.0248
#              결국:	0.0248
#              주인:	0.0246
#              되는:	0.0244
#              않고:	0.0243
#             기억에:	0.0242
#          관람객음악이:	0.0242
#              혼자:	0.0239
#             예쁘고:	0.0238
#              즐거:	0.0238
#             완벽한:	0.0238
#              것이:	0.0237
#              근데:	0.0237
#           관람객영상:	0.0236
#              여주:	0.0233
#              나도:	0.0233
#             만드는:	0.0232
#              이루:	0.0231
#              꿈이:	0.0231
#             보다가:	0.0229
#             보세요:	0.0228
#              ㅋㅋ:	0.0228
#            재밌어요:	0.0228
#             ost:	0.0226
#              역시:	0.0226
#             로맨스:	0.0225
#             감정이:	0.0224
#              저는:	0.0223
#              완전:	0.0223
#              나의:	0.0219
#              꿈에:	0.0219
#              동화:	0.0219
#              끝나:	0.0218
#              ㅜㅜ:	0.0217
#             행복한:	0.0216
#             좋았습:	0.0216
#          관람객최고의:	0.0215
#              아쉬:	0.0213
#            좋았습니:	0.0212
#              봐서:	0.0209
#              위플:	0.0209
#              봐도:	0.0209
#              부분:	0.0209
#              아직:	0.0208
#              기억:	0.0208
#              매우:	0.0206
#              로맨:	0.0206
#              만든:	0.0206
#              to:	0.0205
#              보다:	0.0205
#              몰입:	0.0204
#              엄청:	0.0203
#              뻔한:	0.0202
#              고슬:	0.0202
#             같아요:	0.0201
#            관람객마:	0.0200
#            호불호가:	0.0200
#              예쁜:	0.0200
#              작품:	0.0199
#           관람객노래:	0.0199
#              이건:	0.0197
#              같아:	0.0197
#             갈수록:	0.0197
#              :):	0.0197
#          관람객영상미:	0.0197
#           재밌었어요:	0.0196
#            관람객꿈:	0.0195
#              꿈은:	0.0194
#          관람객음악과:	0.0194
#              피아:	0.0193
#             아니라:	0.0191
#              강추:	0.0191
#              제일:	0.0190
#              열정:	0.0189
#              배경:	0.0188
#             황홀한:	0.0187
#              봐야:	0.0186
#              없었:	0.0186
#              만들:	0.0186
#              그렇:	0.0186
#              공감:	0.0186
#             봤습니:	0.0185
#           관람객진짜:	0.0185
#              봤습:	0.0185
#              이렇:	0.0184
#             위플래:	0.0184
#              이해:	0.0184
#              나오:	0.0183
#              그래:	0.0183
#            극장에서:	0.0182
#              있어:	0.0182
#              매력:	0.0182
#              다소:	0.0181
#           관람객꿈을:	0.0181
#              os:	0.0181
#              오래:	0.0180
#              개인:	0.0180
#             나오는:	0.0179
#              것을:	0.0179
#              맘에:	0.0179
#              이게:	0.0178
#              이상:	0.0177
#             감정을:	0.0177
#             좋네요:	0.0176
#             그래서:	0.0174
#              봤다:	0.0174
#         관람객오랜만에:	0.0174
#              볼만:	0.0174
#           관람객그냥:	0.0173
#            아름답게:	0.0173
#              않았:	0.0172
#              어떤:	0.0172
#              눈과:	0.0171
#             이해가:	0.0171
#              표현:	0.0171
#              아쉽:	0.0171
#              예술:	0.0170
#              없이:	0.0170
#              순간:	0.0169
#         관람객영상미가:	0.0168
#         관람객너무너무:	0.0168
#             좋았음:	0.0168
#              20:	0.0168
#            환상적인:	0.0167
#             얼마나:	0.0167
#              둘이:	0.0167
#             개인적:	0.0165
#              있을:	0.0165
#             호불호:	0.0165
#            위플래쉬:	0.0164
#           잘봤습니다:	0.0163
#             좋았던:	0.0163
#              듯한:	0.0162
#              ^^:	0.0162
#              시작:	0.0161
#           2016년:	0.0160
#            관람객노:	0.0160
#              봤어:	0.0159
#              흘러:	0.0159
#           관람객재밌:	0.0158
#              그저:	0.0158
#             기분이:	0.0158
#              싶다:	0.0158
#             환상적:	0.0157
#             있지만:	0.0157
#          관람객음악도:	0.0157
#              빠져:	0.0157
#              보세:	0.0156
#            잊혀지지:	0.0155
#             오프닝:	0.0155
#              초반:	0.0155
#              정도:	0.0154
#              오늘:	0.0154
#              먹먹:	0.0153
#              전혀:	0.0153
#              필요:	0.0153
#             잔잔한:	0.0152
#             굉장히:	0.0152
#              전개:	0.0152
#           관람객마지:	0.0151
#             모르고:	0.0151
#         관람객라라랜드:	0.0151
#         관람객인생영화:	0.0151
#              예쁘:	0.0151
#             서로의:	0.0150
#             you:	0.0150
#              연주:	0.0150
#              자꾸:	0.0149
#              없고:	0.0149
#            개인적으:	0.0149
#            관람객내:	0.0148
#             서로를:	0.0148
#             때문에:	0.0147
#            아름답다:	0.0147
#            just:	0.0147
#             분위기:	0.0147
#           관람객인생:	0.0147
#            관람객두:	0.0146
#              괜찮:	0.0146
#             전개가:	0.0146
#             한편의:	0.0145
#             그들의:	0.0145
#           관람객아름:	0.0144
#              !!:	0.0144
#              더욱:	0.0144
#            좋습니다:	0.0143
#              보여:	0.0143
#            관람객이:	0.0143
#              잔잔:	0.0143
#              느껴:	0.0142
#              듣고:	0.0142
#             재밌었:	0.0142
#              젊은:	0.0141
#              미소:	0.0141
#             이영화:	0.0141
#              남주:	0.0140
#              제가:	0.0140
#              꾸는:	0.0140
#            관람객뮤:	0.0140
#              낭만:	0.0140
#            관람객최:	0.0140
#           관람객뮤지:	0.0139
#             봤네요:	0.0139
#            관람객정:	0.0139
#            2016:	0.0138
#              향해:	0.0138
#              해피:	0.0138
#             OST:	0.0137
#              미아:	0.0137
#           관람객최고:	0.0136
#              이거:	0.0135
#             남네요:	0.0135
#            좋았지만:	0.0135
#           관람객좋은:	0.0134
#              진심:	0.0134
#          관람객여운이:	0.0134
#              모습:	0.0134
#          관람객노래가:	0.0134
#            마법같은:	0.0134
#              꿈꾸:	0.0133
#              다만:	0.0133
#             아니고:	0.0132
#            관람객인:	0.0132
#          관람객결말이:	0.0132
#              이후:	0.0132
#             했지만:	0.0132
#            아름다웠:	0.0131
#             아쉬운:	0.0131
#              나를:	0.0131
#             제대로:	0.0131
#              남녀:	0.0130
#              마법:	0.0130
#            관람객여:	0.0130
#              연인:	0.0130
#             그러나:	0.0130
#             모습이:	0.0129
#              노잼:	0.0129
#              무슨:	0.0128
#             간만에:	0.0128
#              못한:	0.0128
#              좋음:	0.0128
#             최악의:	0.0128
#              구성:	0.0128
#            해피엔딩:	0.0128
#             오랜만:	0.0128
#             훌륭한:	0.0127
#             오히려:	0.0127
#              인상:	0.0127
#              있고:	0.0127
#             즐겁게:	0.0127
#              극장:	0.0126
#             the:	0.0126
#              호불:	0.0126
#              오랜:	0.0126
#            관람객좋:	0.0126
#              따라:	0.0125
#              마치:	0.0125
#              들어:	0.0125
#            없었다.:	0.0125
#              끝까:	0.0124
#              있지:	0.0124
#           관람객올해:	0.0124
#             재밌는:	0.0123
#             이쁘고:	0.0123
#           관람객재미:	0.0123
#              한편:	0.0122
#              잊혀:	0.0122
#              눈이:	0.0122
#              훌륭:	0.0122
#             이토록:	0.0122
#             눈빛이:	0.0121
#            꼭보세요:	0.0121
#             모르겠:	0.0121
#             갑자기:	0.0121
#              감성:	0.0121
#              여러:	0.0121
#             다미엔:	0.0120
#             누구나:	0.0120
#              라고:	0.0120
#              깊은:	0.0120
#              나름:	0.0119
#              들었:	0.0119
#             즐겁고:	0.0119
#              그때:	0.0119
#              아련:	0.0118
#              대사:	0.0118
#              즐겁:	0.0118
#             충분히:	0.0118
#             따뜻한:	0.0117
#              후반:	0.0117
#              느끼:	0.0117
#           관람객보는:	0.0117
#            관람객감:	0.0117
#              바로:	0.0117
#           관람객꿈과:	0.0117
#             않지만:	0.0116
#           크리스마스:	0.0116
#              선택:	0.0116
#              만드:	0.0116
#             진부한:	0.0116
#              높은:	0.0116
#              펑펑:	0.0115
#             모르게:	0.0114
#              만족:	0.0114
#              후회:	0.0114
#              상상:	0.0114
#              따뜻:	0.0114
#             만들어:	0.0114
#            같습니다:	0.0114
#             동시에:	0.0114
#         관람객재미있게:	0.0113
#              눈을:	0.0113
#           관람객처음:	0.0113
#              그들:	0.0113
#             201:	0.0113

# %%
for word, r in sorted(lset.items(), key=lambda x:x[1], reverse=True)[:500]:
    if len(word) == 1:
        continue
    print('%15s:\t%.4f' % (word, r))
# Out:
#              영화:	1.2473
#             관람객:	0.6936
#              관람:	0.6360
#              너무:	0.5613
#              정말:	0.2651
#             영화.:	0.2534
#             마지막:	0.2387
#              음악:	0.2181
#            아름다운:	0.1476
#             최고의:	0.1401
#              보고:	0.1387
#             뮤지컬:	0.1379
#             여운이:	0.1342
#              진짜:	0.1340
#              꿈을:	0.1340
#              최고:	0.1273
#              사랑:	0.1221
#             영화를:	0.1189
#              아름:	0.1182
#              좋았:	0.1180
#              좋은:	0.1126
#              영상:	0.1054
#              노래:	0.1010
#              그냥:	0.0985
#             스토리:	0.0974
#              마지:	0.0953
#              생각:	0.0933
#              현실:	0.0925
#              다시:	0.0925
#             영화가:	0.0917
#              인생:	0.0916
#              좋고:	0.0877
#              지루:	0.0866
#             영화!:	0.0864
#              여운:	0.0847
#              보는:	0.0840
#             영화는:	0.0827
#             아름다:	0.0819
#           관람객너무:	0.0815
#              계속:	0.0800
#              뮤지:	0.0794
#              좋아:	0.0784
#              많이:	0.0774
#              있는:	0.0768
#              조금:	0.0762
#              감동:	0.0762
#             그리고:	0.0760
#             음악이:	0.0749
#              스토:	0.0739
#              장면:	0.0739
#              남는:	0.0737
#              하는:	0.0724
#             영상미:	0.0720
#              모두:	0.0695
#             음악과:	0.0676
#              재미:	0.0650
#              연기:	0.0648
#              재밌:	0.0645
#              사람:	0.0634
#              결말:	0.0628
#              느낌:	0.0626
#              ㅠㅠ:	0.0621
#            인생영화:	0.0615
#             눈물이:	0.0613
#              처음:	0.0607
#              내내:	0.0605
#             봤는데:	0.0593
#              이런:	0.0590
#              같은:	0.0589
#              모든:	0.0588
#             라이언:	0.0578
#              of:	0.0576
#            라라랜드:	0.0562
#            아름답고:	0.0561
#              대한:	0.0557
#             하지만:	0.0554
#            마지막에:	0.0545
#             좋아요:	0.0537
#            좋았어요:	0.0534
#           관람객정말:	0.0531
#              올해:	0.0525
#             결말이:	0.0522
#            현실적인:	0.0516
#              재즈:	0.0512
#             이렇게:	0.0503
#             음악도:	0.0503
#           영화입니다:	0.0501
#              꿈과:	0.0495
#              연출:	0.0487
#              기대:	0.0486
#              별로:	0.0485
#              눈물:	0.0475
#              없는:	0.0474
#              내가:	0.0470
#              평점:	0.0462
#             영화였:	0.0455
#             중간에:	0.0453
#              그런:	0.0451
#              함께:	0.0449
#              엔딩:	0.0447
#              배우:	0.0442
#             노래가:	0.0436
#              보면:	0.0435
#              슬픈:	0.0433
#             너무나:	0.0433
#              가장:	0.0430
#            영화..:	0.0428
#              가슴:	0.0424
#             아름답:	0.0421
#             좋았다:	0.0417
#             이야기:	0.0410
#              특히:	0.0408
#              한번:	0.0407
#             재밌게:	0.0406
#              위한:	0.0402
#              ㅎㅎ:	0.0401
#           관람객음악:	0.0400
#              마음:	0.0399
#              ..:	0.0398
#              그리:	0.0396
#              아니:	0.0395
#              하나:	0.0395
#          관람객마지막:	0.0395
#              엠마:	0.0394
#           좋았습니다:	0.0391
#            관람객영:	0.0387
#              멋진:	0.0387
#             영화에:	0.0384
#           개인적으로:	0.0383
#              않은:	0.0383
#              귀가:	0.0381
#              감독:	0.0380
#              서로:	0.0377
#              내용:	0.0374
#             가슴이:	0.0371
#              라라:	0.0371
#             현실적:	0.0369
#             배우들:	0.0369
#              행복:	0.0364
#          영화입니다.:	0.0362
#              10:	0.0361
#             인생영:	0.0361
#             음악은:	0.0358
#              약간:	0.0357
#             끝까지:	0.0356
#             영화의:	0.0355
#             라라랜:	0.0353
#            관람객재:	0.0352
#             피아노:	0.0350
#              남자:	0.0345
#             노래도:	0.0341
#            관람객음:	0.0337
#              싶은:	0.0336
#              않는:	0.0335
#             장면이:	0.0332
#              나는:	0.0331
#              기분:	0.0330
#            좋아하는:	0.0330
#              많은:	0.0328
#              추천:	0.0327
#              아주:	0.0324
#           관람객영화:	0.0324
#            배우들의:	0.0323
#             마음이:	0.0322
#             그래도:	0.0321
#            오랜만에:	0.0315
#            봤습니다:	0.0314
#              중간:	0.0311
#              감정:	0.0310
#             느낌이:	0.0310
#            뮤지컬을:	0.0309
#              뭔가:	0.0309
#              보기:	0.0309
#             영화다:	0.0308
#            스토리가:	0.0308
#             좋았어:	0.0307
#             음악,:	0.0306
#              다른:	0.0306
#              완벽:	0.0306
#             사랑을:	0.0305
#              말이:	0.0304
#              하고:	0.0302
#              시간:	0.0301
#              아닌:	0.0301
#             아직도:	0.0300
#             영화입:	0.0300
#             생각이:	0.0299
#            엠마스톤:	0.0298
#             고슬링:	0.0298
#            영화!!:	0.0297
#            영화입니:	0.0296
#              색감:	0.0296
#            영화네요:	0.0295
#              있었:	0.0295
#              우리:	0.0294
#              같다:	0.0291
#         관람객아름다운:	0.0289
#              눈빛:	0.0288
#             끝나고:	0.0286
#          관람객뮤지컬:	0.0286
#             지루한:	0.0286
#              두번:	0.0283
#             봤어요:	0.0281
#              라이:	0.0280
#              이야:	0.0279
#              주는:	0.0275
#              살짝:	0.0274
#              하지:	0.0274
#             주인공:	0.0273
#             즐거운:	0.0272
#             재미있:	0.0271
#              대해:	0.0268
#          좋았습니다.:	0.0267
#             좋아하:	0.0267
#              같이:	0.0267
#              좋다:	0.0266
#             영화라:	0.0266
#            좋았다.:	0.0264
#              있다:	0.0264
#              봤는:	0.0263
#              황홀:	0.0262
#              슬프:	0.0261
#              지금:	0.0260
#              위해:	0.0260
#             사람들:	0.0260
#              여자:	0.0258
#              보러:	0.0258
#             그렇게:	0.0258
#           추천합니다:	0.0257
#             지루하:	0.0256
#             꿈꾸는:	0.0256
#              환상:	0.0255
#             좋았고:	0.0254
#            스토리도:	0.0254
#          영화였습니다:	0.0253
#             슬프고:	0.0253
#             보고싶:	0.0251
#            관람객너:	0.0251
#              없다:	0.0251
#           영화였어요:	0.0250
#         영화였습니다.:	0.0250
#            관람객아:	0.0249
#             감동적:	0.0249
#              모르:	0.0248
#             솔직히:	0.0248
#           영화...:	0.0248
#              결국:	0.0248
#              주인:	0.0246
#              되는:	0.0244
#              않고:	0.0243
#            영화였다:	0.0243
#             기억에:	0.0242
#            영상미와:	0.0242
#          관람객음악이:	0.0242
#             사랑이:	0.0239
#              혼자:	0.0239
#             예쁘고:	0.0238
#              즐거:	0.0238
#             완벽한:	0.0238
#             같다.:	0.0238
#              것이:	0.0237
#              근데:	0.0237
#           관람객영상:	0.0236
#            영화에요:	0.0235
#           영화관에서:	0.0234
#              여주:	0.0233
#              나도:	0.0233
#             만드는:	0.0232
#              이루:	0.0231
#              꿈이:	0.0231
#             영화관:	0.0231
#             보다가:	0.0229
#           뮤지컬영화:	0.0229
#             보세요:	0.0228
#              ㅋㅋ:	0.0228
#            재밌어요:	0.0228
#             영화,:	0.0228
#             ...:	0.0227
#             ost:	0.0226
#              역시:	0.0226
#             감동이:	0.0225
#             로맨스:	0.0225
#             감독의:	0.0224
#             감정이:	0.0224
#              저는:	0.0223
#              완전:	0.0223
#             마음에:	0.0222
#             보면서:	0.0222
#             10점:	0.0222
#            보는내내:	0.0221
#            영화라고:	0.0220
#              나의:	0.0219
#              꿈에:	0.0219
#              동화:	0.0219
#              끝나:	0.0218
#             영상이:	0.0217
#              ㅜㅜ:	0.0217
#             행복한:	0.0216
#             내용이:	0.0216
#             좋았습:	0.0216
#          관람객최고의:	0.0215
#            영상미가:	0.0214
#          라이언고슬링:	0.0214
#           봤습니다.:	0.0213
#              아쉬:	0.0213
#            좋았습니:	0.0212
#             사랑에:	0.0211
#            너무너무:	0.0210
#              봐서:	0.0209
#             영화중:	0.0209
#              위플:	0.0209
#              봐도:	0.0209
#              부분:	0.0209
#              아직:	0.0208
#              기억:	0.0208
#             연기도:	0.0208
#            재미있게:	0.0207
#              매우:	0.0206
#             사랑과:	0.0206
#              로맨:	0.0206
#              만든:	0.0206
#              to:	0.0205
#              보다:	0.0205
#             엔딩이:	0.0204
#              몰입:	0.0204
#              엄청:	0.0203
#              뻔한:	0.0202
#              고슬:	0.0202
#            영화다.:	0.0201
#             지루했:	0.0201
#             같아요:	0.0201
#            관람객마:	0.0200
#             사람이:	0.0200
#            호불호가:	0.0200
#            중간중간:	0.0200
#              예쁜:	0.0200
#             내용도:	0.0200
#              작품:	0.0199
#             영화로:	0.0199
#           관람객노래:	0.0199
#            스토리는:	0.0198
#             기대를:	0.0198
#              이건:	0.0197
#              같아:	0.0197
#             갈수록:	0.0197

# %%
for idx, r in sorted(rank.items(), key=lambda x:x[1], reverse=True)[:500]:
    token = kr_wordrank.int2token(idx)
    if (len(token[0]) == 1) or (token[1] == 'R'):
        continue
    print('%15s:\t%.4f' % (token, r))
# Out:
#     ('영화', 'L'):	1.2473
#    ('관람객', 'L'):	0.6936
#     ('관람', 'L'):	0.6360
#     ('너무', 'L'):	0.5613
#     ('정말', 'L'):	0.2651
#    ('영화.', 'L'):	0.2534
#    ('마지막', 'L'):	0.2387
#     ('음악', 'L'):	0.2181
#   ('아름다운', 'L'):	0.1476
#    ('최고의', 'L'):	0.1401
#     ('보고', 'L'):	0.1387
#    ('뮤지컬', 'L'):	0.1379
#    ('여운이', 'L'):	0.1342
#     ('진짜', 'L'):	0.1340
#     ('꿈을', 'L'):	0.1340
#     ('최고', 'L'):	0.1273
#     ('사랑', 'L'):	0.1221
#    ('영화를', 'L'):	0.1189
#     ('아름', 'L'):	0.1182
#     ('좋았', 'L'):	0.1180
#     ('좋은', 'L'):	0.1126
#     ('영상', 'L'):	0.1054
#     ('노래', 'L'):	0.1010
#     ('그냥', 'L'):	0.0985
#    ('스토리', 'L'):	0.0974
#     ('마지', 'L'):	0.0953
#     ('생각', 'L'):	0.0933
#     ('현실', 'L'):	0.0925
#     ('다시', 'L'):	0.0925
#    ('영화가', 'L'):	0.0917
#     ('인생', 'L'):	0.0916
#     ('좋고', 'L'):	0.0877
#     ('지루', 'L'):	0.0866
#    ('영화!', 'L'):	0.0864
#     ('여운', 'L'):	0.0847
#     ('보는', 'L'):	0.0840
#    ('영화는', 'L'):	0.0827
#    ('아름다', 'L'):	0.0819
#  ('관람객너무', 'L'):	0.0815
#     ('계속', 'L'):	0.0800
#     ('뮤지', 'L'):	0.0794
#     ('좋아', 'L'):	0.0784
#     ('많이', 'L'):	0.0774
#     ('있는', 'L'):	0.0768
#     ('조금', 'L'):	0.0762
#     ('감동', 'L'):	0.0762
#    ('그리고', 'L'):	0.0760
#    ('음악이', 'L'):	0.0749
#     ('스토', 'L'):	0.0739
#     ('장면', 'L'):	0.0739
#     ('남는', 'L'):	0.0737
#     ('하는', 'L'):	0.0724
#    ('영상미', 'L'):	0.0720
#     ('모두', 'L'):	0.0695
#    ('음악과', 'L'):	0.0676
#     ('재미', 'L'):	0.0650
#     ('연기', 'L'):	0.0648
#     ('재밌', 'L'):	0.0645
#     ('사람', 'L'):	0.0634
#     ('결말', 'L'):	0.0628
#     ('느낌', 'L'):	0.0626
#     ('ㅠㅠ', 'L'):	0.0621
#   ('인생영화', 'L'):	0.0615
#    ('눈물이', 'L'):	0.0613
#     ('처음', 'L'):	0.0607
#     ('내내', 'L'):	0.0605
#    ('봤는데', 'L'):	0.0593
#     ('이런', 'L'):	0.0590
#     ('같은', 'L'):	0.0589
#     ('모든', 'L'):	0.0588
#    ('라이언', 'L'):	0.0578
#     ('of', 'L'):	0.0576
#   ('라라랜드', 'L'):	0.0562
#   ('아름답고', 'L'):	0.0561
#     ('대한', 'L'):	0.0557
#    ('하지만', 'L'):	0.0554
#   ('마지막에', 'L'):	0.0545
#    ('좋아요', 'L'):	0.0537
#   ('좋았어요', 'L'):	0.0534
#  ('관람객정말', 'L'):	0.0531
#     ('올해', 'L'):	0.0525
#    ('결말이', 'L'):	0.0522
#   ('현실적인', 'L'):	0.0516
#     ('재즈', 'L'):	0.0512
#    ('이렇게', 'L'):	0.0503
#    ('음악도', 'L'):	0.0503
#  ('영화입니다', 'L'):	0.0501
#     ('꿈과', 'L'):	0.0495
#     ('연출', 'L'):	0.0487
#     ('기대', 'L'):	0.0486
#     ('별로', 'L'):	0.0485
#     ('눈물', 'L'):	0.0475
#     ('없는', 'L'):	0.0474
#     ('내가', 'L'):	0.0470
#     ('평점', 'L'):	0.0462
#    ('영화였', 'L'):	0.0455
#    ('중간에', 'L'):	0.0453
#     ('그런', 'L'):	0.0451
#     ('함께', 'L'):	0.0449
#     ('엔딩', 'L'):	0.0447
#     ('배우', 'L'):	0.0442
#    ('노래가', 'L'):	0.0436
#     ('보면', 'L'):	0.0435
#     ('슬픈', 'L'):	0.0433
#    ('너무나', 'L'):	0.0433
#     ('가장', 'L'):	0.0430
#   ('영화..', 'L'):	0.0428
#     ('가슴', 'L'):	0.0424
#    ('아름답', 'L'):	0.0421
#    ('좋았다', 'L'):	0.0417
#    ('이야기', 'L'):	0.0410
#     ('특히', 'L'):	0.0408
#     ('한번', 'L'):	0.0407
#    ('재밌게', 'L'):	0.0406
#     ('위한', 'L'):	0.0402
#     ('ㅎㅎ', 'L'):	0.0401
#  ('관람객음악', 'L'):	0.0400
#     ('마음', 'L'):	0.0399
#     ('..', 'L'):	0.0398
#     ('그리', 'L'):	0.0396
#     ('아니', 'L'):	0.0395
#     ('하나', 'L'):	0.0395
# ('관람객마지막', 'L'):	0.0395
#     ('엠마', 'L'):	0.0394
#  ('좋았습니다', 'L'):	0.0391
#   ('관람객영', 'L'):	0.0387
#     ('멋진', 'L'):	0.0387
#    ('영화에', 'L'):	0.0384
#  ('개인적으로', 'L'):	0.0383
#     ('않은', 'L'):	0.0383
#     ('귀가', 'L'):	0.0381
#     ('감독', 'L'):	0.0380
#     ('서로', 'L'):	0.0377
#     ('내용', 'L'):	0.0374
#    ('가슴이', 'L'):	0.0371
#     ('라라', 'L'):	0.0371
#    ('현실적', 'L'):	0.0369
#    ('배우들', 'L'):	0.0369
#     ('행복', 'L'):	0.0364
# ('영화입니다.', 'L'):	0.0362
#     ('10', 'L'):	0.0361
#    ('인생영', 'L'):	0.0361
#    ('음악은', 'L'):	0.0358
#     ('약간', 'L'):	0.0357
#    ('끝까지', 'L'):	0.0356
#    ('영화의', 'L'):	0.0355
#    ('라라랜', 'L'):	0.0353
#   ('관람객재', 'L'):	0.0352
#    ('피아노', 'L'):	0.0350
#     ('남자', 'L'):	0.0345
#    ('노래도', 'L'):	0.0341
#   ('관람객음', 'L'):	0.0337
#     ('싶은', 'L'):	0.0336
#     ('않는', 'L'):	0.0335
#    ('장면이', 'L'):	0.0332
#     ('나는', 'L'):	0.0331
#     ('기분', 'L'):	0.0330
#   ('좋아하는', 'L'):	0.0330
#     ('많은', 'L'):	0.0328
#     ('추천', 'L'):	0.0327
#     ('아주', 'L'):	0.0324
#  ('관람객영화', 'L'):	0.0324
#   ('배우들의', 'L'):	0.0323
#    ('마음이', 'L'):	0.0322
#    ('그래도', 'L'):	0.0321
#   ('오랜만에', 'L'):	0.0315
#   ('봤습니다', 'L'):	0.0314
#     ('중간', 'L'):	0.0311
#     ('감정', 'L'):	0.0310
#    ('느낌이', 'L'):	0.0310
#   ('뮤지컬을', 'L'):	0.0309
#     ('뭔가', 'L'):	0.0309
#     ('보기', 'L'):	0.0309
#    ('영화다', 'L'):	0.0308
#   ('스토리가', 'L'):	0.0308
#    ('좋았어', 'L'):	0.0307
#    ('음악,', 'L'):	0.0306
#     ('다른', 'L'):	0.0306
#     ('완벽', 'L'):	0.0306
#    ('사랑을', 'L'):	0.0305
#     ('말이', 'L'):	0.0304
#     ('하고', 'L'):	0.0302
#     ('시간', 'L'):	0.0301
#     ('아닌', 'L'):	0.0301
#    ('아직도', 'L'):	0.0300
#    ('영화입', 'L'):	0.0300
#    ('생각이', 'L'):	0.0299
#   ('엠마스톤', 'L'):	0.0298
#    ('고슬링', 'L'):	0.0298
#   ('영화!!', 'L'):	0.0297
#   ('영화입니', 'L'):	0.0296
#     ('색감', 'L'):	0.0296
#   ('영화네요', 'L'):	0.0295
#     ('있었', 'L'):	0.0295
#     ('우리', 'L'):	0.0294
#     ('같다', 'L'):	0.0291
# ('관람객아름다운', 'L'):	0.0289
#     ('눈빛', 'L'):	0.0288
#    ('끝나고', 'L'):	0.0286
# ('관람객뮤지컬', 'L'):	0.0286
#    ('지루한', 'L'):	0.0286
#     ('두번', 'L'):	0.0283
#    ('봤어요', 'L'):	0.0281
#     ('라이', 'L'):	0.0280
#     ('이야', 'L'):	0.0279
#     ('주는', 'L'):	0.0275
#     ('살짝', 'L'):	0.0274
#     ('하지', 'L'):	0.0274
#    ('주인공', 'L'):	0.0273
#    ('즐거운', 'L'):	0.0272
#    ('재미있', 'L'):	0.0271
#     ('대해', 'L'):	0.0268
# ('좋았습니다.', 'L'):	0.0267
#    ('좋아하', 'L'):	0.0267
#     ('같이', 'L'):	0.0267
#     ('좋다', 'L'):	0.0266
#    ('영화라', 'L'):	0.0266
#   ('좋았다.', 'L'):	0.0264
#     ('있다', 'L'):	0.0264
#     ('봤는', 'L'):	0.0263
#     ('황홀', 'L'):	0.0262
#     ('슬프', 'L'):	0.0261
#     ('지금', 'L'):	0.0260
#     ('위해', 'L'):	0.0260
#    ('사람들', 'L'):	0.0260
#     ('여자', 'L'):	0.0258
#     ('보러', 'L'):	0.0258
#    ('그렇게', 'L'):	0.0258
#  ('추천합니다', 'L'):	0.0257
#    ('지루하', 'L'):	0.0256
#    ('꿈꾸는', 'L'):	0.0256
#     ('환상', 'L'):	0.0255
#    ('좋았고', 'L'):	0.0254
#   ('스토리도', 'L'):	0.0254
# ('영화였습니다', 'L'):	0.0253
#    ('슬프고', 'L'):	0.0253

# %%
for text in texts:
    if '응원해주는' in text:
        print(text.replace('응원해주는', '[응원해주는]'))
# Out:
# OST, 영상미, 배우들의 연기, 스토리까지 완벽했다. 일과 사랑을 모두 진실하게 해나가려는 fools의 삶을 [응원해주는] 영화. 마지막 10분을 잊을 수 없다.
# 관심사 같은 연인을 만난다는게 쉽지않은데 재즈 하나로 즐거워하는 둘을 보며 엄마미소지어졌던 나는 저런 연애를 하고 있을까 나도 고슬링과 같이 연인의 꿈을 [응원해주는]가 나를 되돌아보았던 장면마다 찌릿하게 와닿을 때가 많았다 왠지모르게 울컥하고 여운남는~
# 넌 할 수있어, 무조건 할수있어, 넌 잘하고 있어, 누가 뭐래도 넌 잘될거야라고 외처주고, 소리쳐준다. 용기잃고 좌절하고 불안해하는, 꿈을 두려워하는 모든이를 힘차게 [응원해주는] 영화. 그리고 셉.
# 사랑하는 여자의 꿈을 [응원해주는] 남자의 모습이 너무 아름다웠다. 그런데 세바스찬과 미아가 왜 마지막에 결혼하지 못한건지 너무 이해가 안갔다ㅜㅜ 서로 수고했다는듯이 눈인사나눌때 눈물이... 세바스찬과 미아가 연결되는 해피엔딩으로 다시 재개봉하길...ㅜㅜ
# 꿈을 [응원해주는] 멋진 영화
# 함께 꿈을 [응원해주는] 내편이 있으면 좋겠다는 생각을 했다. 라이언 고슬링, 엠마스톤 연기 그리고 스토리, 영상이 훌륭하다.
# 뜻밖의 선물같은 영화 음악도 배우도 줄거리도 좋았다 둘의 인연은 끝났어도 서로의행복을 [응원해주는] 마지막 미소
# 관람객결말이 좋았다.  서로에 대한 꿈을 [응원해주는] 그런 연애. 노래들과 퍼포먼스도 좋아씀
# 우리가 살며 선택의 기로에 봉착하지만 각자 가는길에 서로가 [응원해주는] 아름다운연인 멋진 뮤지컬 이것이 인생이다
# 이 영화의 클라이 맥스는 처음 장면으로 돌아가 해고 당하고 키스하는거였다. 왜인지 모를 짜릿함. 현실적이지만 각자의 삶을 [응원해주는] 그 모습이 멋있었다. 감독이 말하고자 하는 라라랜드가 무엇인지 느낄 수 있었음.
# 관람객꿈꾸는 그대들의 찌질함, 눈물, 콧물을 열렬히 [응원해주는] 영화!  이시국에도 이 영화를 보고온 지금, 12월 낭만적이야~
